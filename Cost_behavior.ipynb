# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarahisaacs/2026-Fall-305/blob/main/Cost_behavior.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cost Behavior Analysis
#
# ### cost accounting 1 - Riverband Manufacturing
#
# we have 24 months of production and cost data.
# our job is to work out how each cost behaves when the number of units produced changes.
# cost driver (activity base):Units_Produced

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/cost_behavior_data.csv')

# display(df.info())
display(df.head())
display(df.tail())
display(df.sample(n=5))
display(df.iloc[0])
display (df.describe())
# Out:
#       Month  Units_Produced  Factory_Rent  Supervisor_Salary  \
# 0  Jan-2024            4900         12000              18000
# 1  Feb-2024            4600         12000              18000
# 2  Mar-2024            6100         12000              18000
# 3  Apr-2024            7400         12000              18000
# 4  May-2024            8300         12000              18000
#
#    Direct_Materials  Direct_Labor  Utilities  Maintenance  Quality_Inspection
# 0             41650         29400       9625         5709                4500
# 1             39100         27600       9277         5409                4500
# 2             51850         36600      11100         6021                9000
# 3             62900         44400      12670         7431                9000
# 4             70550         49800      13834         8214                9000
#        Month  Units_Produced  Factory_Rent  Supervisor_Salary  \
# 19  Aug-2025           12600         12000              18000
# ...
